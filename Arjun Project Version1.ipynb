# %% [markdown]
# # <h1 style="background-color:cyan;"> <center> Smartphone Analysis Report

# %% [markdown]
# ### 1. Problem Statement

# %% [markdown]
# This dataset contains various attributes of different smartphone models from multiple brands. The dataset includes information such as price, rating, 5G and NFC support, processor details, battery capacity, display, and camera specifications.
#
# Explore and analyze the data to uncover trends and analyze the distribution of key features.

# %% [markdown]
# ### 2. About the Dataset

# %% [markdown]
# The Smartphone dataset comprises 210 rows and 26 columns, detailing various attributes of different smartphone models from multiple brands.
#
# Feature Description:
#
# 1.brand_name : Brand name of Smartphone
#
# 2.model: Various smartphone models from different brands.
#
# 3.price: Price of diffrent smartphone models
#
# 4.rating: Customer ratings for various models.
#
# 5.has_5g: Is the smartphone capable of connecting to a 5G network
#
# 6.has_nfc: Does the smartphone have Near Field Communication (NFC) capabilities
#
# 7.has_ir_blaster: Does the smartphone have irs blaster capabilities
#
# 8.processor_brand: Brand name of the processor
#
# 9.num_cores: No of cores used in the processor
#
# 10.processor_speed: Speed of the processor
#
# 11.battery_capacity: Storage Capacityof the battery
#
# 12.fast_charging_available: Whether the smartphone supporting the fast charging or not
#
# 13.fast_charging: Smartphone charging watts
#
# 14.ram_capacity: Temproray memory storagge of the smartphone
#
# 15.internal_memory: Smartphone storage capacity
#
# 16.refresh_rate: Smartphone screen refresh rate
#
# 17.num_rear_cameras: No of rear cameras in the smartphone
#
# 18.num_front_cameras: No of front cameras in the smartphone
#
# 19.os: Operatin system of the smartphone
#
# 20.primary_camera_rear: Resolution of rear primary camera
#
# 21.primary_camera_front: Resolution of front primary camera
#
# 22.extended_memory_available: whether the smartphone supporting extended memory feature or not.
#
# 23.extended_upto: Mmaximum storage capacity of extended storage.
#
# 24.resolution_width: screen resolution width.
#
# 25.resolution_height: screen resolution height.

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading the dataset

# %%
data = pd.read_csv('./smartphones_cleaned_v6.csv')

# %%
data.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# ...

# %%
data.tail()
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 975    False           False      snapdragon        8.0             3.00  ...
# 976    False           False      snapdragon        8.0             2.20  ...
# 977     True            True       dimensity        8.0             2.85  ...
# 978     True           False      snapdragon        8.0             2.20  ...
# 979    False           False             NaN        8.0              NaN  ...
#
#      refresh_rate  num_rear_cameras  num_front_cameras       os  \
# ...

# %% [markdown]
# ### Dataset information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %% [markdown]
# ### Display the description of the integer columns of a dataframe

# %%
data.describe()
# Out:
#                price      rating   num_cores  processor_speed  \
# count     980.000000  879.000000  974.000000       938.000000
# mean    32520.504082   78.258248    7.772074         2.427217
# std     39531.812669    7.402854    0.836845         0.464090
# min      3499.000000   60.000000    4.000000         1.200000
# 25%     12999.000000   74.000000    8.000000         2.050000
# 50%     19994.500000   80.000000    8.000000         2.300000
# 75%     35491.500000   84.000000    8.000000         2.840000
# max    650000.000000   89.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        969.000000               980.000000     769.000000    980.000000
# mean        4817.748194                 0.854082      46.126138      6.560204
# std         1009.540054                 0.353205      34.277870      2.744378
# min         1821.000000                 0.000000      10.000000      1.000000
# ...

# %% [markdown]
# ### Gives total number of rows and columns

# %%
data.size
# Out:
# 25480

# %%
data.shape
# Out:
# (980, 26)

# %% [markdown]
# ## 3.DATA PREPROCESSING

# %% [markdown]
# ### Identify missing values percentage

# %%
data.isnull().mean()*100
# Out:
# brand_name                    0.000000
# model                         0.000000
# price                         0.000000
# rating                       10.306122
# has_5g                        0.000000
# has_nfc                       0.000000
# has_ir_blaster                0.000000
# processor_brand               2.040816
# num_cores                     0.612245
# processor_speed               4.285714
# battery_capacity              1.122449
# fast_charging_available       0.000000
# fast_charging                21.530612
# ram_capacity                  0.000000
# internal_memory               0.000000
# screen_size                   0.000000
# refresh_rate                  0.000000
# num_rear_cameras              0.000000
# num_front_cameras             0.408163
# os                            1.428571
# primary_camera_rear           0.000000
# primary_camera_front          0.510204
# extended_memory_available     0.000000
# extended_upto                48.979592
# ...

# %% [markdown]
# ### Dropping Un Wanted Feature

# %%
data.drop(columns ='extended_upto',inplace =True)

# %% [markdown]
# ### Dropping missing values

# %%
data.dropna(inplace =True)

# %%
data.isnull().mean()*100
# Out:
# brand_name                   0.0
# model                        0.0
# price                        0.0
# rating                       0.0
# has_5g                       0.0
# has_nfc                      0.0
# has_ir_blaster               0.0
# processor_brand              0.0
# num_cores                    0.0
# processor_speed              0.0
# battery_capacity             0.0
# fast_charging_available      0.0
# fast_charging                0.0
# ram_capacity                 0.0
# internal_memory              0.0
# screen_size                  0.0
# refresh_rate                 0.0
# num_rear_cameras             0.0
# num_front_cameras            0.0
# os                           0.0
# primary_camera_rear          0.0
# primary_camera_front         0.0
# extended_memory_available    0.0
# resolution_width             0.0
# resolution_height            0.0
# dtype: float64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (678, 25)

# %%
data.brand_name.unique()
# Out:
# array(['oneplus', 'samsung', 'realme', 'xiaomi', 'nothing', 'oppo',
#        'vivo', 'poco', 'motorola', 'iqoo', 'jio', 'tecno', 'infinix',
#        'cola', 'leeco', 'honor', 'google', 'nubia', 'redmi', 'asus',
#        'oukitel', 'nokia', 'huawei', 'sony', 'zte', 'lenovo', 'apple',
#        'lava', 'letv', 'itel', 'lg', 'doogee', 'tcl', 'blackview'],
#       dtype=object)

# %% [markdown]
# # <center> Univariate graphs

# %% [markdown]
# ### <center> Model wise comparisson

# %%
plt.figure(figsize =(10,6))
sns.histplot(data = data, x = 'brand_name')
plt.xticks(rotation =75)
plt.title('Model distribution')
plt.show()

# %% [markdown]
# ### <center> PRICE DISTRIBUTION

# %%
sns.boxenplot(data=data, y='price')
plt.title('PRICE DISTRIBUTION')
plt.show()

# %% [markdown]
# ### <center> Battery capacity Distribution

# %%
sns.kdeplot(x =data.battery_capacity)
plt.title('Battery capacity Distribution')
plt.show()

# %% [markdown]
# # <center> Bivariate Graphs

# %% [markdown]
# ### <center> Comparison between Brand and Price

# %%
plt.figure(figsize =(10,8))
sns.barplot(data=data, x ='price', y ='brand_name')
plt.title('Brand VS Price')
plt.show()

# %% [markdown]
# ### <center> Market treng by 5G support

# %%
sns.countplot(data=data,x ='has_5g')
plt.title('5G Trend')
plt.show()

# %% [markdown]
# ### <center> Rating VS 5G Support

# %%
sns.barplot(data=data, x ='has_5g', y ='rating')
plt.title('Rating VS 5G')
plt.show()

# %% [markdown]
# ### <center> Processor Distribution

# %%
sns.countplot(data=data, x ='processor_brand')
plt.xticks(rotation =75)
plt.title('Processor')
plt.show()

# %% [markdown]
# ### <center> Rating VS Processor Speed

# %%
sns.scatterplot(data=data, x ='processor_speed', y ='rating', hue ='processor_brand')
plt.title('Rating VS Processor Speed')
plt.show()

# %% [markdown]
# ### <center> RAM capacity Distribution

# %%
sns.countplot(data=data, x='ram_capacity')
plt.title('RAM capacity Distribution')
plt.show()

# %% [markdown]
# ### <center> Rating VS Internal Memory

# %%
sns.scatterplot(data=data, x ='internal_memory', y ='rating', hue ='processor_brand')
plt.title('Rating VS Internal Memory')
plt.show()

# %% [markdown]
# ### <center> Rating VS Refresh Rate

# %%
sns.regplot(data=data, x ='refresh_rate', y ='rating')
plt.title('Rating VS Refresh Rate')
plt.show()

# %% [markdown]
# ### <center> Rating VS Rear Camera

# %%
sns.regplot(data=data, x ='primary_camera_rear', y ='rating')
plt.title('Rating VS Rear Camera')
plt.show()

# %% [markdown]
# ### <center> Rating VS Front Camera

# %%
sns.regplot(data=data, x ='primary_camera_front', y ='rating')
plt.title('Rating VS Front Camera')
plt.show()

# %% [markdown]
# ### <center> Rating VS Battery

# %%
sns.lineplot(data=data, x ='rating', y ='battery_capacity')
plt.title('Rating VS Battery')
plt.show()

# %% [markdown]
# ### <center> Operating  System

# %%
sns.countplot(data=data, x ='os')
plt.title('Operating System')
plt.show()

# %% [markdown]
# ### <center> Screen Size VS Price

# %%
sns.scatterplot(data=data,x ='price', y ='screen_size')
plt.title('ScreenSize VS Price')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The analysis of the smartphone dataset has unveiled several significant trends in the smartphone market. Leading brands such as Xiaomi, Realme, Samsung, Vivo, and Oppo are dominating the market with their diverse range of models. The majority of smartphones fall within the lower to mid-range price categories. A notable finding is the positive correlation between battery capacity and price, suggesting that higher-priced smartphones generally offer superior battery performance.
#
# Luxury smartphones are primarily produced by Huawei, Apple, and Asus. The demand for phones supporting 5G network is increasing, making them the most sought-after devices in the market. The Snapdragon processor is the most commonly used in smartphones. RAM capacities typically range from 4GB to 8GB, which are standard configurations for modern smartphones.
#
# Furthermore, there is a positive correlation between ratings and internal memory. This dataset offers valuable insights for manufacturers, consumers, and analysts interested in the smartphone industry.
